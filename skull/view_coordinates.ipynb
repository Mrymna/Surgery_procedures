# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# From mm/10 to mm

# %%
df = pd.read_csv("mouse_skull_coordinates.csv",sep="\t")
df = df*10
df.to_csv("mouse_skull_coordinates_mm.csv")

# %%
df = pd.read_csv("mouse_skull_coordinates_mm.csv")

# %%
plt.figure(figsize=(10,10))
plt.gca().set_aspect('equal', adjustable='box')
plt.scatter(df.x,df.y,s=20,c=df.z)
plt.colorbar()
print(np.max(df.z))
print(np.min(df.z))
# Out:
# 0.2
# -2.6

# %%
print(df.y.value_counts())
# Out:
# -4.9    11
# -2.9    11
# -0.9    11
# -1.9    11
# -3.9    11
#  0.1     9
#  2.1     9
#  1.1     9
#  3.1     7
#  4.1     7
# -5.9     7
#  5.1     5
#  6.1     5
#  7.1     5
#  8.1     4
# -6.9     3
# -6.8     3
# -5.7     2
# -6.6     1
# -6.5     1
#  0.0     1
# Name: y, dtype: int64

# %%
np.sum(df.y==4.1)

#plt.scatter(df1.x,df1.z)
# Out:
# 0
